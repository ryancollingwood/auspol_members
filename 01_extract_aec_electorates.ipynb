# %%
from bs4 import BeautifulSoup
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from time import sleep

# %% [markdown]
# # AEC Localitites
#
# The Australian Electoral Commission websites has a page where you can search for localities by postcode or electorate.
#
# We will scrape these pages for every electorate in the representives we exported from theyvoteforyou.org.au

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 84.0.4147
# [WDM] - Get LATEST driver version for 84.0.4147
# [WDM] - Driver [C:\Users\ryanc\.wdm\drivers\chromedriver\win32\84.0.4147.30\chromedriver.exe] found in cache

# %% [markdown]
# # Read in Representatives
#
# Then get the unique electorates

# %%
representatives_df = pd.read_csv("02_transform_they_vote_for_you/output.csv")

# %%
electorates = list(representatives_df["electorate"].unique())

# %% [markdown]
# Defining a function for getting a url for a specific electorate.

# %%
def get_electorate_url(electorate):
    return f'https://electorate.aec.gov.au/LocalitySearchResults.aspx?filter={electorate}&filterby=Electorate'

# %% [markdown]
# # Navigating to Page and Dealing with Pagnation
#
# Import to have a sleep between requests so we don't deny-listed.

# %%
def get_max_pages(df):
    # get the maximum number of pages
    pages_df = df.T
    pages_df.columns = ["pages"]
    pages_df["pages"] = pd.to_numeric(pages_df["pages"], errors ="coerce")
    
    more_pages = any(pages_df["pages"].isnull())
    
    try:
        max_pages = pages_df["pages"].max()
    except:
        max_pages = None
        
    return max_pages, more_pages

# %%
def get_next_page_data(browser, for_page, electorate):   
    print(f"\tgetting page {for_page} for {electorate}")

    browser.links.find_by_text(str(page)).click()
    sleep(0.5)

    # extract pages from browser html
    tables = pd.read_html(browser.html)

    max_pages, more_pages = get_max_pages(tables[1])
    
    return tables[0], max_pages, more_pages

# %% [markdown]
# Now this bit of code could do with some refatoring as there's a lot of repeated logic. Part of the challenge is we're having to step through multiple sub-pages and finding out if there are more pages due to the "..." link

# %%
for electorate in electorates:

    url = get_electorate_url(electorate)

    # list for storing the localities
    locality_dfs = list()

    # first navigate to page
    browser.visit(url)
    sleep(1)
    
    # counter for the current page
    current_page = 1

    # the result of this is a list of dataframes
    # the first being the locality data (electorate / postcode)
    # the second being the number of pages
    tables = pd.read_html(browser.html)

    # determine the number of max pages
    max_pages, more_pages = get_max_pages(tables[1])
    
    print(f"{electorate} - number of pages {max_pages}")

    # get the first locality data
    locality_dfs.append(tables[0])

    # interate over each of the pages
    # skipping the first page as we already the data
    if isinstance(max_pages, int):
        for page in range(current_page + 1, max_pages + 1):
            
            data_df, next_max_pages, more_pages = get_next_page_data(
                browser, page, electorate
            )
            
            locality_dfs.append(data_df)
        
        current_page = page
        max_pages = next_max_pages
        
        # handle the "..." more pages link
        while more_pages:
            for page in range(current_page + 1, max_pages + 1):

                data_df, max_pages, more_pages = get_next_page_data(
                    browser, page, electorate
                )

                locality_dfs.append(data_df)            
            
    # if more_pages:
    electorate_df = pd.concat(locality_dfs)
    electorate_df.to_csv(f"01_extract_aec_electorates/{electorate}.csv", index = False)
# Out:
# Grayndler - number of pages 2
# 	getting page 2 for Grayndler
# Menzies - number of pages 2
# 	getting page 2 for Menzies
# Cunningham - number of pages 3
# 	getting page 2 for Cunningham
# 	getting page 3 for Cunningham
# Watson - number of pages 2
# 	getting page 2 for Watson
# Holt - number of pages nan
# Blaxland - number of pages 2
# 	getting page 2 for Blaxland
# Franklin - number of pages 5.0
# Isaacs - number of pages 2
# 	getting page 2 for Isaacs
# Dickson - number of pages 3
# 	getting page 2 for Dickson
# 	getting page 3 for Dickson
# Richmond - number of pages 5.0
# Hunter - number of pages 5.0
# Mitchell - number of pages nan
# Flinders - number of pages 3
# 	getting page 2 for Flinders
# 	getting page 3 for Flinders
# Swan - number of pages 2
# 	getting page 2 for Swan
# Ballarat - number of pages 5.0
# Bowman - number of pages 2
# 	getting page 2 for Bowman
# Farrer - number of pages 5.0
# Forrest - number of pages 5.0
# Corio - number of pages 2
# 	getting page 2 for Corio
# Cook - number of pages 2
# 	getting page 2 for Cook
# Blair - number of pages 5.0
# Gorton - number of pages 2
# 	getting page 2 for Gorton
# Parramatta - number of pages 2
# 	getting page 2 for Parramatta
# Moreton - number of pages 2
# 	getting page 2 for Moreton
# Sydney - number of pages 3
# 	getting page 2 for Sydney
# 	getting page 3 for Sydney
# Grey - number of pages 5.0
# Kingston - number of pages 2
# 	getting page 2 for Kingston
# Fadden - number of pages 2
# 	getting page 2 for Fadden
# Maribyrnong - number of pages 2
# 	getting page 2 for Maribyrnong
# Lingiari - number of pages 5.0
# Calwell - number of pages 2
# 	getting page 2 for Calwell
# Makin - number of pages 2
# 	getting page 2 for Makin
# Gippsland - number of pages 5.0
# Bradfield - number of pages 2
# 	getting page 2 for Bradfield
# Dawson - number of pages 5.0
# Flynn - number of pages 5.0
# Forde - number of pages 3
# 	getting page 2 for Forde
# 	getting page 3 for Forde
# Hasluck - number of pages 3
# 	getting page 2 for Hasluck
# 	getting page 3 for Hasluck
# Leichhardt - number of pages 5.0
# McEwen - number of pages 4
# 	getting page 2 for McEwen
# 	getting page 3 for McEwen
# 	getting page 4 for McEwen
# Melbourne - number of pages 2
# 	getting page 2 for Melbourne
# Kooyong - number of pages nan
# Wannon - number of pages 5.0
# Riverina - number of pages 5.0
# Fowler - number of pages 2
# 	getting page 2 for Fowler
# McPherson - number of pages 2
# 	getting page 2 for McPherson
# Aston - number of pages nan
# Chifley - number of pages 2
# 	getting page 2 for Chifley
# Hughes - number of pages 2
# 	getting page 2 for Hughes
# Greenway - number of pages nan
# McMahon - number of pages 2
# 	getting page 2 for McMahon
# Wright - number of pages 5.0
# Bonner - number of pages 2
# 	getting page 2 for Bonner
# Banks - number of pages 2
# 	getting page 2 for Banks
# Barker - number of pages 5.0
# Bendigo - number of pages 5.0
# Capricornia - number of pages 5.0
# Deakin - number of pages 2
# 	getting page 2 for Deakin
# Durack - number of pages 5.0
# Gellibrand - number of pages 2
# 	getting page 2 for Gellibrand
# Hinkler - number of pages 5
# 	getting page 2 for Hinkler
# 	getting page 3 for Hinkler
# 	getting page 4 for Hinkler
# 	getting page 5 for Hinkler
# Hotham - number of pages 2
# 	getting page 2 for Hotham
# Hume - number of pages 5.0
# Kingsford Smith - number of pages 2
# 	getting page 2 for Kingsford Smith
# La Trobe - number of pages 2
# 	getting page 2 for La Trobe
# Lalor - number of pages nan
# Lyne - number of pages 5.0
# Moore - number of pages nan
# Newcastle - number of pages 3
# 	getting page 2 for Newcastle
# 	getting page 3 for Newcastle
# O'Connor - number of pages 5.0
# Page - number of pages 5.0
# Pearce - number of pages 5.0
# Petrie - number of pages nan
# Rankin - number of pages 2
# 	getting page 2 for Rankin
# Robertson - number of pages 4
# 	getting page 2 for Robertson
# 	getting page 3 for Robertson
# 	getting page 4 for Robertson
# Scullin - number of pages nan
# Griffith - number of pages 2
# 	getting page 2 for Griffith
# Casey - number of pages 4
# 	getting page 2 for Casey
# 	getting page 3 for Casey
# 	getting page 4 for Casey
# Canning - number of pages 5
# 	getting page 2 for Canning
# 	getting page 3 for Canning
# 	getting page 4 for Canning
# 	getting page 5 for Canning
# North Sydney - number of pages 3
# 	getting page 2 for North Sydney
# 	getting page 3 for North Sydney
# Barton - number of pages 2
# 	getting page 2 for Barton
# Burt - number of pages nan
# Cowan - number of pages 2
# 	getting page 2 for Cowan
# Dobell - number of pages 4
# 	getting page 2 for Dobell
# 	getting page 3 for Dobell
# 	getting page 4 for Dobell
# Eden-Monaro - number of pages 5.0
# Fairfax - number of pages 3
# 	getting page 2 for Fairfax
# 	getting page 3 for Fairfax
# Lyons - number of pages 5.0
# Macarthur - number of pages 2
# 	getting page 2 for Macarthur
# Macquarie - number of pages 5
# 	getting page 2 for Macquarie
# 	getting page 3 for Macquarie
# 	getting page 4 for Macquarie
# 	getting page 5 for Macquarie
# Paterson - number of pages 5
# 	getting page 2 for Paterson
# 	getting page 3 for Paterson
# 	getting page 4 for Paterson
# 	getting page 5 for Paterson
# Solomon - number of pages 4
# 	getting page 2 for Solomon
# 	getting page 3 for Solomon
# 	getting page 4 for Solomon
# Mackellar - number of pages 3
# 	getting page 2 for Mackellar
# 	getting page 3 for Mackellar
# Oxley - number of pages 2
# 	getting page 2 for Oxley
# Brisbane - number of pages 3
# 	getting page 2 for Brisbane
# 	getting page 3 for Brisbane
# Boothby - number of pages 4
# 	getting page 2 for Boothby
# 	getting page 3 for Boothby
# 	getting page 4 for Boothby
# Calare - number of pages 5.0
# Brand - number of pages 2
# 	getting page 2 for Brand
# Bruce - number of pages nan
# Shortland - number of pages 4
# 	getting page 2 for Shortland
# 	getting page 3 for Shortland
# 	getting page 4 for Shortland
# Tangney - number of pages 2
# 	getting page 2 for Tangney
# Wills - number of pages nan
# Berowra - number of pages 3
# 	getting page 2 for Berowra
# 	getting page 3 for Berowra
# Groom - number of pages 5.0
# Maranoa - number of pages 5.0
# Wide Bay - number of pages 5.0
# Goldstein - number of pages nan
# Werriwa - number of pages 2
# 	getting page 2 for Werriwa
# Fisher - number of pages 4
# 	getting page 2 for Fisher
# 	getting page 3 for Fisher
# 	getting page 4 for Fisher
# Fenner - number of pages 2
# 	getting page 2 for Fenner
# Whitlam - number of pages 4
# 	getting page 2 for Whitlam
# 	getting page 3 for Whitlam
# 	getting page 4 for Whitlam
# Parkes - number of pages 5.0
# Kennedy - number of pages 5.0
# New England - number of pages 5.0
# Bennelong - number of pages 2
# 	getting page 2 for Bennelong
# Perth - number of pages 2
# 	getting page 2 for Perth
# Mayo - number of pages 5.0
# Fremantle - number of pages 2
# 	getting page 2 for Fremantle
# Bass - number of pages 5.0
# Braddon - number of pages 5.0
# Canberra - number of pages 3
# 	getting page 2 for Canberra
# 	getting page 3 for Canberra
# Chisholm - number of pages 2
# 	getting page 2 for Chisholm
# Corangamite - number of pages 5.0
# Cowper - number of pages 5.0
# Curtin - number of pages 2
# 	getting page 2 for Curtin
# Dunkley - number of pages nan
# Fraser - number of pages 2
# 	getting page 2 for Fraser
# Gilmore - number of pages 5.0
# Herbert - number of pages 4
# 	getting page 2 for Herbert
# 	getting page 3 for Herbert
# 	getting page 4 for Herbert
# Higgins - number of pages 2
# 	getting page 2 for Higgins
# Indi - number of pages 5.0
# Jagajaga - number of pages 2
# 	getting page 2 for Jagajaga
# Lilley - number of pages 2
# 	getting page 2 for Lilley
# Lindsay - number of pages 2
# 	getting page 2 for Lindsay
# Longman - number of pages 3
# 	getting page 2 for Longman
# 	getting page 3 for Longman
# Macnamara - number of pages 2
# 	getting page 2 for Macnamara
# Mallee - number of pages 5.0
# Moncrieff - number of pages 2
# 	getting page 2 for Moncrieff
# Reid - number of pages 2
# 	getting page 2 for Reid
# Ryan - number of pages 2
# 	getting page 2 for Ryan
# Stirling - number of pages 2
# 	getting page 2 for Stirling
# Sturt - number of pages 4
# 	getting page 2 for Sturt
# 	getting page 3 for Sturt
# 	getting page 4 for Sturt
# Warringah - number of pages 2
# 	getting page 2 for Warringah
# Wentworth - number of pages 2
# 	getting page 2 for Wentworth
# Adelaide - number of pages 4
# 	getting page 2 for Adelaide
# 	getting page 3 for Adelaide
# 	getting page 4 for Adelaide
# Monash - number of pages 5.0
# Hindmarsh - number of pages 3
# 	getting page 2 for Hindmarsh
# 	getting page 3 for Hindmarsh
# Spence - number of pages 4
# 	getting page 2 for Spence
# 	getting page 3 for Spence
# 	getting page 4 for Spence
# Clark - number of pages 2
# 	getting page 2 for Clark
# Nicholls - number of pages 5.0
# Cooper - number of pages 2
# 	getting page 2 for Cooper
# Bean - number of pages 4
# 	getting page 2 for Bean
# 	getting page 3 for Bean
# 	getting page 4 for Bean
